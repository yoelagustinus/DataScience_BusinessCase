# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import datetime
import xlrd

# %%
workbook_sls = xlrd.open_workbook('sales_data.xls')

# %%
worksheet_sls = workbook_sls.sheet_by_name('Sheet 1')

# %%
data_sls = []
header_sls = []
for col_sls in range(worksheet_sls.ncols):
    cell_value = worksheet_sls.cell_value(0, col_sls)
    header_sls.append(cell_value)

for row_sls in range(1, worksheet_sls.nrows):
    row_data_sls = []
    for col_sls in range(worksheet_sls.ncols):
        cell_value = worksheet_sls.cell_value(row_sls, col_sls)
        row_data_sls.append(cell_value)
    data_sls.append(row_data_sls)

# %%
df_sales = pd.DataFrame(data_sls, columns = header_sls)
df_sales
# Out:
#        KEY_STORE  DAY_OF_WEEK   DAY_DT    SALES  CUSTOMERS
# 0          200.0          7.0  44682.0  31091.0      456.0
# 1          203.0          7.0  44682.0  14103.0      328.0
# 2          205.0          7.0  44682.0   6832.0      245.0
# 3          206.0          7.0  44682.0  13528.0      346.0
# 4          213.0          7.0  44682.0   7069.0      293.0
# ...          ...          ...      ...      ...        ...
# 55390      991.0          7.0  45046.0    484.0       93.0
# 55391      992.0          7.0  45046.0   2465.0      192.0
# 55392      994.0          7.0  45046.0    948.0       91.0
# 55393      995.0          7.0  45046.0   1524.0      132.0
# 55394      996.0          7.0  45046.0    535.0      106.0
#
# [55395 rows x 5 columns]

# %%
df_sales.describe(include='all')
# Out:
#           KEY_STORE   DAY_OF_WEEK        DAY_DT         SALES     CUSTOMERS
# count  55395.000000  55395.000000  55395.000000  55395.000000  55395.000000
# mean     637.892066      4.002780  44868.385667   2129.330848    203.220273
# std      284.370312      2.000124    105.709136   2489.417318     77.765859
# min      200.000000      1.000000  44682.000000      0.000000      1.000000
# 25%      335.000000      2.000000  44777.000000    866.000000    153.000000
# 50%      725.000000      4.000000  44872.000000   1440.000000    202.000000
# 75%      911.000000      6.000000  44960.000000   2498.000000    252.000000
# max      996.000000      7.000000  45046.000000  49407.000000    566.000000

# %%
workbook_str = xlrd.open_workbook('store_data.xls')
worksheet_str = workbook_str.sheet_by_name('Sheet 1')

# %%
data_str = []
header_str = []
for col_str in range(worksheet_str.ncols):
    cell_value = worksheet_str.cell_value(0, col_str)
    header_str.append(cell_value)

for row_str in range(1, worksheet_str.nrows):
    row_data_str = []
    for col_str in range(worksheet_str.ncols):
        cell_value = worksheet_str.cell_value(row_str, col_str)
        row_data_str.append(cell_value)
    data_str.append(row_data_str)

# %%
df_store = pd.DataFrame(data_str, columns = header_str)
df_store
# Out:
#      LOC_KEY LOC_IDNT LOC_TYPE_CDE  DISTT_KEY  REGN_KEY  AREA_KEY  CHAIN_KEY  \
# 0      200.0      221            S       21.0       3.0       1.0        1.0
# 1      203.0      227            S       20.0       3.0       1.0        1.0
# 2      205.0      233            S       20.0       3.0       1.0        1.0
# 3      206.0      235            S       21.0       3.0       1.0        1.0
# 4      213.0      252            S       21.0       3.0       1.0        1.0
# ..       ...      ...          ...        ...       ...       ...        ...
# 176    991.0      404            S       46.0       1.0       1.0        1.0
# 177    992.0      408            S       43.0       3.0       1.0        1.0
# 178    994.0      212            S       23.0       3.0       1.0        1.0
# 179    995.0      402            S       25.0       3.0       1.0        1.0
# 180    996.0      407            S       43.0       3.0       1.0        1.0
#
#      CMPY_KEY  CRNCY_CDE_KEY  DM_RECD_LOAD_DT  ... LOC_STORE_VOL_CAT  \
# 0         1.0            1.0          42767.0  ...
# 1         1.0            1.0          42767.0  ...
# 2         1.0            1.0          42767.0  ...
# 3         1.0            1.0          42767.0  ...
# 4         1.0            1.0          42767.0  ...
# ..        ...            ...              ...  ...               ...
# 176       1.0            1.0          44916.0  ...
# 177       1.0            1.0          44916.0  ...
# 178       1.0            1.0          44917.0  ...
# 179       1.0            1.0          44917.0  ...
# 180       1.0            1.0          44917.0  ...
#
#      LOC_PAY_CAT LOC_ACCT_CLK_ID LOC_NO_LOAD_DOCKS LOC_NO_UNLOAD_DOCKS  \
# 0
# 1
# 2
# 3
# 4
# ..           ...             ...               ...                 ...
# 176
# 177
# 178
# 179
# 180
#
#     LOC_REMODEL_DT LOC_START_DT LOC_END_DT DM_RECD_CLOSE_DT       LOC_COUNTY
# 0                       38707.0                    929273.0  SULAWESI-MALUKU
# 1                       41116.0                    929273.0             JAWA
# 2                       41102.0                    929273.0           MADURA
# 3                       41215.0                    929273.0  SULAWESI-MALUKU
# 4                       40997.0                    929273.0  SULAWESI-MALUKU
# ..             ...          ...        ...              ...              ...
# 176                     44980.0                    929273.0             JAWA
# 177                     44958.0                    929273.0       KALIMANTAN
# 178                     45015.0                    929273.0             JAWA
# 179                     45003.0                    929273.0             JAWA
# 180                     45017.0                    929273.0             BALI
#
# [181 rows x 69 columns]

# %%
df_store.describe(include='all')
# Out:
#            LOC_KEY LOC_IDNT LOC_TYPE_CDE   DISTT_KEY    REGN_KEY    AREA_KEY  \
# count   181.000000      181          181  181.000000  181.000000  181.000000
# unique         NaN      181            1         NaN         NaN         NaN
# top            NaN      221            S         NaN         NaN         NaN
# freq           NaN        1          181         NaN         NaN         NaN
# mean    685.812155      NaN          NaN   29.574586    2.016575    1.033149
# std     288.003391      NaN          NaN   12.427175    1.051323    0.179523
# min     200.000000      NaN          NaN    9.000000    1.000000    1.000000
# 25%     363.000000      NaN          NaN   20.000000    1.000000    1.000000
# 50%     808.000000      NaN          NaN   25.000000    1.000000    1.000000
# 75%     932.000000      NaN          NaN   41.000000    3.000000    1.000000
# max     996.000000      NaN          NaN   46.000000    4.000000    2.000000
#
#          CHAIN_KEY  CMPY_KEY  CRNCY_CDE_KEY  DM_RECD_LOAD_DT  ...  \
# count   181.000000     181.0          181.0       181.000000  ...
# unique         NaN       NaN            NaN              NaN  ...
# top            NaN       NaN            NaN              NaN  ...
# freq           NaN       NaN            NaN              NaN  ...
# mean      1.033149       1.0            1.0     43917.138122  ...
# std       0.179523       0.0            0.0       824.997722  ...
# min       1.000000       1.0            1.0     42767.000000  ...
# 25%       1.000000       1.0            1.0     42767.000000  ...
# 50%       1.000000       1.0            1.0     44035.000000  ...
# 75%       1.000000       1.0            1.0     44573.000000  ...
# max       2.000000       1.0            1.0     44917.000000  ...
#
#        LOC_STORE_VOL_CAT  LOC_PAY_CAT LOC_ACCT_CLK_ID LOC_NO_LOAD_DOCKS  \
# count                181          181             181               181
# unique                 1            1               1                 1
# top
# freq                 181          181             181               181
# mean                 NaN          NaN             NaN               NaN
# std                  NaN          NaN             NaN               NaN
# min                  NaN          NaN             NaN               NaN
# 25%                  NaN          NaN             NaN               NaN
# 50%                  NaN          NaN             NaN               NaN
# 75%                  NaN          NaN             NaN               NaN
# max                  NaN          NaN             NaN               NaN
#
#        LOC_NO_UNLOAD_DOCKS LOC_REMODEL_DT  LOC_START_DT LOC_END_DT  \
# count                  181            181    181.000000        181
# unique                   1              1           NaN          1
# top                                                 NaN
# freq                   181            181           NaN        181
# mean                   NaN            NaN  40667.077348        NaN
# std                    NaN            NaN   3606.433838        NaN
# min                    NaN            NaN  31478.000000        NaN
# 25%                    NaN            NaN  38493.000000        NaN
# 50%                    NaN            NaN  41215.000000        NaN
# 75%                    NaN            NaN  43958.000000        NaN
# max                    NaN            NaN  45017.000000        NaN
#
#        DM_RECD_CLOSE_DT LOC_COUNTY
# count             181.0        181
# unique              NaN          9
# top                 NaN       JAWA
# freq                NaN        113
# mean           929273.0        NaN
# std                 0.0        NaN
# min            929273.0        NaN
# 25%            929273.0        NaN
# 50%            929273.0        NaN
# 75%            929273.0        NaN
# max            929273.0        NaN
#
# [11 rows x 69 columns]

# %% [markdown]
# # Explore Dataset
# ## Dataset Sales

# %%
# Let's see if we have any missing data, luckily we don't!
# sns.heatmap(sales_train_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
sns.heatmap(df_sales.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >

# %%
df_sales.hist(bins = 30, figsize = (10,10), color = 'r')

# Data is not distributed among all stores so its there some bias
# Average sales around Rp. 1000-120.000
# Store Everyday its open
# Out:
# array([[<Axes: title={'center': 'KEY_STORE'}>,
#         <Axes: title={'center': 'DAY_OF_WEEK'}>],
#        [<Axes: title={'center': 'DAY_DT'}>,
#         <Axes: title={'center': 'SALES'}>],
#        [<Axes: title={'center': 'CUSTOMERS'}>, <Axes: >]], dtype=object)

# %%
df_sales['CUSTOMERS'].max()
# Out:
# 566.0

# %% [markdown]
# ## Explore data Store

# %%
# Let's see if we have any missing data in the store information dataframe!
sns.heatmap(df_store.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >

# %%
df_store.hist(bins = 30, figsize = (10,10), color = 'r')
# Out:
# array([[<Axes: title={'center': 'LOC_KEY'}>,
#         <Axes: title={'center': 'DISTT_KEY'}>,
#         <Axes: title={'center': 'REGN_KEY'}>],
#        [<Axes: title={'center': 'AREA_KEY'}>,
#         <Axes: title={'center': 'CHAIN_KEY'}>,
#         <Axes: title={'center': 'CMPY_KEY'}>],
#        [<Axes: title={'center': 'CRNCY_CDE_KEY'}>,
#         <Axes: title={'center': 'DM_RECD_LOAD_DT'}>,
#         <Axes: title={'center': 'DM_RECD_LAST_UPDT_DT'}>],
#        [<Axes: title={'center': 'LOC_VAT_REGN'}>,
#         <Axes: title={'center': 'LOC_START_DT'}>,
#         <Axes: title={'center': 'DM_RECD_CLOSE_DT'}>]], dtype=object)
